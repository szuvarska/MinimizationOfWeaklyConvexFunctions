# %%
import torch

x = torch.rand(5, 3)
print(x)
# Out:
# tensor([[0.1622, 0.2396, 0.1350],
#         [0.3713, 0.4473, 0.9935],
#         [0.7824, 0.3005, 0.2763],
#         [0.2840, 0.6848, 0.6720],
#         [0.0891, 0.1669, 0.2669]])
